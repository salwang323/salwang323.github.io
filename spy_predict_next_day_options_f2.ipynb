# %% [markdown]
# <a href="https://colab.research.google.com/github/salwang323/salwang323.github.io/blob/master/spy_predict_next_day_options_f2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from yfinance.utils import retreive_financial_details
from tensorflow.python.ops.gen_array_ops import reshape
import tensorflow as tf
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import pandas_datareader.data as pdr
import datetime as dt
from keras.optimizers import Adam
from keras.initializers import RandomUniform 


seed_value = 42
tf.random.set_seed(seed_value)
features = 3

start_date = dt.datetime(2020, 1, 1)
end_date = dt.datetime.now()
#end_date = dt.datetime(2023, 6, 4)
symbol = 'qqq'  # Replace with the ticker symbol of the stock you want to fetch data for
df = yf.download(symbol, start=start_date, end=end_date)

df['PriceTimeVolume'] = df['Close'] * df['Volume']
df['VWAP_C'] = df['PriceTimeVolume'].cumsum() / df['Volume'].cumsum()


c = df["Close"].values.reshape(-1,1)
o = df["Open"].values.reshape(-1,1)
v = df["Volume"].values.reshape(-1,1)

d_r = []
for i in range(1, len(c)):
  ret_v = (c[i] - c[i-1])/c[i-1]
  d_r.append(ret_v)

print(df.tail())

# 归一化处理
scaler0 = MinMaxScaler()
scaler1 = MinMaxScaler()
scaler2 = MinMaxScaler()

volatility = np.sqrt(252) * np.array(d_r, dtype = float).std()

print ("volatility = ", volatility)

s_o = scaler0.fit_transform(o)
s_c = scaler1.fit_transform(c)
s_v = scaler2.fit_transform(v)

#print (v)
#print(s_v)

df = np.concatenate((s_o, s_c, s_v), axis = 1)
#df = np.concatenate((s_c, s_v), axis = 1)
#print(df)

# 划分训练集和测试集
train_size = int(len(df) * 1)
print("train_size", train_size)
train_data = df[:train_size+1]
#test_data = df[train_size:]

# 定义时间窗口大小
window_size = 20

# 创建训练集和测试集数据
def create_dataset(data, window_size):
    X, Y = [], []
    len1 = len(data)
    print("len =", len1)
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        Y.append(data[i+window_size])
    return np.array(X), np.array(Y)

X_train, Y_train = create_dataset(train_data, window_size)
#X_test, Y_test = create_dataset(test_data, window_size)

last_timestep = X_train[-1:]
print("last_timestep= ", last_timestep)
print("Y_train")
print(Y_train[-1:])

# 创建 LSTM 模型
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation='relu', input_shape=(window_size, features),kernel_initializer=RandomUniform(seed=seed_value)))
model.add(LSTM(64, activation='relu'))
#model.add(Dense(units=25))
model.add(Dense(features))
#model.compile(optimizer='adam', loss='mse')
optimizer1 = Adam(learning_rate = 0.001)
model.compile(optimizer = 'adam', loss='mse')
#model.add(Dropout(0.1))

# 训练模型
model.fit(X_train, Y_train, epochs=400, batch_size=256, verbose=0)

# 预测测试集数据
#predicted = model.predict(X_test)

# 将预测结果反归一化
#predicted = scaler.inverse_transform(predicted)
#Y_test = scaler.inverse_transform(Y_test)

# predict future values
print("future")
future_predictions = []
for i in range(window_size):
#for i in range(1):
#  print("0:last")
#  print("last_timestep", last_timestep)
  shift = last_timestep[0,1:,:]
  print("shift", shift.shape)

  if (i == 0):
    prediction = Y_train[-1:]
  else:
    prediction = model.predict(last_timestep)
  if ( i == 0):
    print("last day", i, " ", i, prediction)
  future_predictions.append(prediction)
#  print("tomorrow few days", i, " ", scaler.inverse_transform(prediction))
  result = np.concatenate((shift, prediction), axis = 0)
#  print("after cat", result.shape)
  last_timestep = np.expand_dims(result, axis=0)
#  print("after dims add", last_timestep.shape)

#print("after for loop, future_predictions")
print(future_predictions)
dim = np.array(future_predictions).reshape(-1, features)
print(dim)
r_dim = np.split(dim, features, axis = 1)
#predictions = scaler.inverse_transform(two_dim)

s_o = r_dim[0]
s_c= r_dim[1]
v = r_dim[2]
o= scaler0.inverse_transform(s_o)
c= scaler1.inverse_transform(s_c)
v = scaler2.inverse_transform(s_v)
print(v)
print(c)

prediction = np.concatenate((o, c, v), axis = 1)
print(prediction)

# 可视化预测结果
#plt.plot(Y_test[:, 0], color='red', label='True Open Price')
#plt.plot(predicted[:, 0], color='blue', label='Predicted Open Price')
#plt.title('Stock Price Prediction (Open Price)')
#plt.xlabel('Time')
#plt.ylabel('Price')
#plt.legend()
#plt.show()

#plt.plot(Y_test[:, 1], color='red', label='True Close Price')
#plt.plot(predicted[:, 1], color='blue', label='Predicted Close Price')
#plt.title('Stock Price Prediction (Close Price)')
#plt.xlabel('Time')
#plt.ylabel('Price')
#plt.legend()
#plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-06-02  353.799988  355.829987  352.010010  354.649994  354.649994
# 2023-06-05  354.429993  357.500000  353.850006  354.899994  354.899994
# 2023-06-06  354.279999  355.820007  352.929993  354.839996  354.839996
# 2023-06-07  355.130005  357.119995  348.179993  348.820007  348.820007
# 2023-06-08  349.119995  353.619812  348.899994  353.149994  353.149994
#
#               Volume  PriceTimeVolume      VWAP_C
# Date
# 2023-06-02  53293500     1.890054e+10  303.107170
# 2023-06-05  47266200     1.677477e+10  303.160595
# 2023-06-06  41390400     1.468697e+10  303.207235
# 2023-06-07  69225900     2.414738e+10  303.275979
# 2023-06-08  47012227     1.660237e+10  303.326973
# volatility =  0.28653878995490345
# train_size 865
# len = 865
# last_timestep=  [[[0.65288724 0.66402497 0.24536566]
#   [0.65962075 0.66854156 0.15710558]
#   [0.66405278 0.6635562  0.1795837 ]
#   [0.65881102 0.67105549 0.09758771]
#   [0.66115488 0.67263202 0.13385448]
#   [0.67044528 0.68950531 0.17461556]
#   [0.68442354 0.71571006 0.2659288 ]
#   [0.7098657  0.71247184 0.25091082]
#   [0.70458127 0.71728672 0.15021317]
#   [0.70304713 0.69904977 0.17860383]
#   [0.68378432 0.6917636  0.2587105 ]
#   [0.71689755 0.72614942 0.28039108]
#   [0.72380143 0.76313435 0.25934264]
#   [0.77472826 0.76986671 0.31199485]
#   [0.75623264 0.76138735 0.2707976 ]
#   [0.75350525 0.77851641 0.19100591]
#   [0.77937346 0.78976523 0.20631759]
#   [0.78205833 0.79083046 0.17341514]
#   [0.78141911 0.79057482 0.14133972]
#   [0.78504155 0.764924   0.29329101]]]
# Y_train
# [[0.75942889 0.78337382 0.17202873]]
# future
# shift (19, 3)
# last day 0   0 [[0.75942889 0.78337382 0.17202873]]
# shift (19, 3)
# 1/1 [==============================] - 0s 209ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 20ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 18ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 17ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 23ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 20ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 24ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 20ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 19ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 19ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 17ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 21ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 19ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 20ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 22ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 19ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 22ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 17ms/step
# shift (19, 3)
# 1/1 [==============================] - 0s 16ms/step
# [array([[0.75942889, 0.78337382, 0.17202873]]), array([[0.77837914, 0.7865222 , 0.17605391]], dtype=float32), array([[0.7830488 , 0.79089093, 0.1735113 ]], dtype=float32), array([[0.78543246, 0.7933117 , 0.1700767 ]], dtype=float32), array([[0.7887685 , 0.7968971 , 0.16707389]], dtype=float32), array([[0.7923206 , 0.8005264 , 0.16441396]], dtype=float32), array([[0.7960854 , 0.8043594 , 0.16181576]], dtype=float32), array([[0.79997945, 0.8081875 , 0.1596429 ]], dtype=float32), array([[0.80413693, 0.81222576, 0.15756837]], dtype=float32), array([[0.80834264, 0.8164207 , 0.15506244]], dtype=float32), array([[0.8128519 , 0.8208586 , 0.15241641]], dtype=float32), array([[0.817474  , 0.8253338 , 0.14962706]], dtype=float32), array([[0.82203233, 0.82978785, 0.14668693]], dtype=float32), array([[0.8265942 , 0.8342348 , 0.14367968]], dtype=float32), array([[0.83104986, 0.8385003 , 0.14057994]], dtype=float32), array([[0.83565503, 0.8429474 , 0.13768461]], dtype=float32), array([[0.8403676 , 0.8475937 , 0.13487597]], dtype=float32), array([[0.8451859 , 0.8523412 , 0.13177222]], dtype=float32), array([[0.85022867, 0.8573855 , 0.12850672]], dtype=float32), array([[0.85547364, 0.8626206 , 0.1252138 ]], dtype=float32)]
# [[0.75942889 0.78337382 0.17202873]
#  [0.77837914 0.78652221 0.17605391]
#  [0.78304881 0.79089093 0.1735113 ]
#  [0.78543246 0.79331172 0.1700767 ]
#  [0.78876847 0.79689711 0.16707389]
#  [0.79232061 0.80052638 0.16441396]
#  [0.79608542 0.80435938 0.16181576]
#  [0.79997945 0.80818748 0.1596429 ]
#  [0.80413693 0.81222576 0.15756837]
#  [0.80834264 0.81642067 0.15506244]
#  [0.81285191 0.8208586  0.15241641]
#  [0.81747401 0.82533377 0.14962706]
#  [0.82203233 0.82978785 0.14668693]
#  [0.82659417 0.83423477 0.14367968]
#  [0.83104986 0.83850032 0.14057994]
#  [0.83565503 0.84294742 0.13768461]
#  [0.84036762 0.84759372 0.13487597]
#  [0.84518588 0.85234118 0.13177222]
#  [0.85022867 0.85738552 0.12850672]
#  [0.85547364 0.86262059 0.1252138 ]]
# [[3.0969400e+07]
#  [2.7518900e+07]
#  [2.1655300e+07]
#  [2.2139300e+07]
#  [2.6397300e+07]
#  [2.3547000e+07]
#  [2.1898500e+07]
#  [2.2756900e+07]
#  [2.4418100e+07]
#  [2.5742100e+07]
#  [1.8805000e+07]
#  [2.4325200e+07]
#  [2.1146300e+07]
#  [2.0736400e+07]
#  [2.6496100e+07]
#  [3.7436500e+07]
#  [4.2264400e+07]
#  [2.6731900e+07]
#  [2.8924500e+07]
#  [3.9568100e+07]
#  [5.2015800e+07]
#  [2.5408600e+07]
#  [3.0691200e+07]
#  [3.8534800e+07]
#  [2.2467100e+07]
#  [2.5884900e+07]
#  [2.1478900e+07]
#  [3.0198000e+07]
#  [2.4471300e+07]
#  [2.2773200e+07]
#  [2.3438500e+07]
#  [2.4394500e+07]
#  [2.2230500e+07]
#  [4.2604000e+07]
#  [6.6017200e+07]
#  [8.4522600e+07]
#  [9.7743000e+07]
#  [7.9537700e+07]
#  [1.2182260e+08]
#  [1.4817370e+08]
#  [1.1293390e+08]
#  [1.3195350e+08]
#  [7.3086200e+07]
#  [7.8705500e+07]
#  [8.9828400e+07]
#  [1.1642400e+08]
#  [1.0059920e+08]
#  [8.9168800e+07]
#  [1.3782070e+08]
#  [1.3488200e+08]
#  [9.2054400e+07]
#  [1.2125710e+08]
#  [1.1415630e+08]
#  [1.2089650e+08]
#  [1.1898390e+08]
#  [1.2463980e+08]
#  [9.4881800e+07]
#  [8.8754900e+07]
#  [7.9887600e+07]
#  [5.8845000e+07]
#  [4.9356900e+07]
#  [6.2659300e+07]
#  [5.3715400e+07]
#  [5.6465300e+07]
#  [4.7487600e+07]
#  [6.4763500e+07]
#  [6.9904500e+07]
#  [4.5940400e+07]
#  [6.8252600e+07]
#  [4.2853900e+07]
#  [6.3959600e+07]
#  [4.7036000e+07]
#  [6.4657400e+07]
#  [6.2863200e+07]
#  [3.8249100e+07]
#  [7.2932800e+07]
#  [4.0089100e+07]
#  [4.3278500e+07]
#  [3.4231900e+07]
#  [3.6451700e+07]
#  [4.6862800e+07]
#  [4.8716400e+07]
#  [4.3359500e+07]
#  [4.8795000e+07]
#  [3.2841000e+07]
#  [3.7783100e+07]
#  [3.6455200e+07]
#  [3.8624800e+07]
#  [3.1852300e+07]
#  [3.5714100e+07]
#  [4.1054100e+07]
#  [6.5521200e+07]
#  [5.1549300e+07]
#  [5.5747200e+07]
#  [4.2398100e+07]
#  [3.6237300e+07]
#  [3.7417000e+07]
#  [4.3642900e+07]
#  [2.8762400e+07]
#  [3.3055300e+07]
#  [5.5665600e+07]
#  [4.2784300e+07]
#  [5.0691800e+07]
#  [2.5776000e+07]
#  [3.3383400e+07]
#  [3.7228700e+07]
#  [3.8716100e+07]
#  [4.7365600e+07]
#  [3.2937300e+07]
#  [3.5046300e+07]
#  [5.8084400e+07]
#  [7.2919400e+07]
#  [7.2034800e+07]
#  [4.5307400e+07]
#  [4.8890100e+07]
#  [3.4749300e+07]
#  [3.0578600e+07]
#  [4.9422100e+07]
#  [2.4068700e+07]
#  [3.2767400e+07]
#  [4.6032400e+07]
#  [3.6940800e+07]
#  [5.2824600e+07]
#  [3.4377800e+07]
#  [3.8909200e+07]
#  [3.4689200e+07]
#  [3.1956500e+07]
#  [3.4589000e+07]
#  [3.6578200e+07]
#  [3.0426300e+07]
#  [4.0312900e+07]
#  [3.2885300e+07]
#  [6.4108100e+07]
#  [7.2230500e+07]
#  [5.4523900e+07]
#  [4.7594100e+07]
#  [3.5137900e+07]
#  [4.0610100e+07]
#  [4.3243800e+07]
#  [2.9865500e+07]
#  [5.1363500e+07]
#  [5.4054500e+07]
#  [3.6445700e+07]
#  [3.1302400e+07]
#  [2.7556900e+07]
#  [4.1774500e+07]
#  [5.3686300e+07]
#  [3.2081600e+07]
#  [2.4911300e+07]
#  [2.1612100e+07]
#  [2.8048200e+07]
#  [4.4969400e+07]
#  [3.5088400e+07]
#  [4.3104300e+07]
#  [3.8773400e+07]
#  [3.1895700e+07]
#  [3.0799500e+07]
#  [2.4803000e+07]
#  [2.3529500e+07]
#  [3.1999400e+07]
#  [2.7723400e+07]
#  [3.4748900e+07]
#  [3.6418500e+07]
#  [3.4866600e+07]
#  [4.2216700e+07]
#  [4.9482700e+07]
#  [2.8021000e+07]
#  [3.6321000e+07]
#  [3.6216200e+07]
#  [5.0836800e+07]
#  [1.1008330e+08]
#  [1.2395900e+08]
#  [9.9568600e+07]
#  [6.4837900e+07]
#  [6.9667500e+07]
#  [7.1809000e+07]
#  [3.8525200e+07]
#  [4.1849900e+07]
#  [4.2321000e+07]
#  [8.1570800e+07]
#  [8.6251100e+07]
#  [5.7168600e+07]
#  [4.1128900e+07]
#  [4.8837300e+07]
#  [7.0631700e+07]
#  [5.5242400e+07]
#  [5.8438300e+07]
#  [2.7050000e+07]
#  [4.9380800e+07]
#  [5.0020200e+07]
#  [7.5497400e+07]
#  [2.8184600e+07]
#  [4.9704200e+07]
#  [2.7539700e+07]
#  [2.5443300e+07]
#  [3.0201100e+07]
#  [7.9370700e+07]
#  [6.4240000e+07]
#  [3.6949100e+07]
#  [4.2514200e+07]
#  [4.0570700e+07]
#  [3.6756800e+07]
#  [3.2195400e+07]
#  [2.9306100e+07]
#  [3.2196200e+07]
#  [2.4658500e+07]
#  [3.8421100e+07]
#  [3.0559100e+07]
#  [5.3413500e+07]
#  [4.3246300e+07]
#  [6.5838300e+07]
#  [3.9987400e+07]
#  [4.3604100e+07]
#  [7.5728200e+07]
#  [5.2054200e+07]
#  [4.0959800e+07]
#  [8.6537100e+07]
#  [6.9024900e+07]
#  [3.6102900e+07]
#  [3.4414600e+07]
#  [2.4806900e+07]
#  [3.0168400e+07]
#  [2.1843500e+07]
#  [2.8069600e+07]
#  [2.2718400e+07]
#  [2.5907300e+07]
#  [2.6875600e+07]
#  [2.4516800e+07]
#  [2.3326800e+07]
#  [1.7163100e+07]
#  [2.7836200e+07]
#  [2.7521300e+07]
#  [2.3620000e+07]
#  [2.2828700e+07]
#  [1.9332100e+07]
#  [2.0851000e+07]
#  [1.8341500e+07]
#  [4.8839300e+07]
#  [2.7519500e+07]
#  [2.6760400e+07]
#  [2.8804800e+07]
#  [2.5709000e+07]
#  [2.5461900e+07]
#  [2.3730500e+07]
#  [4.1173400e+07]
#  [3.7095500e+07]
#  [2.6176300e+07]
#  [2.1201300e+07]
#  [1.6785000e+07]
#  [2.2497700e+07]
#  [2.5871900e+07]
#  [1.8138100e+07]
#  [2.1611400e+07]
#  [4.5305900e+07]
#  [2.9323400e+07]
#  [5.2809600e+07]
#  [3.0394800e+07]
#  [3.3955800e+07]
#  [3.2746400e+07]
#  [2.9266800e+07]
#  [2.2898400e+07]
#  [2.3500100e+07]
#  [3.5118700e+07]
#  [2.4537000e+07]
#  [3.0728100e+07]
#  [2.5130600e+07]
#  [2.1609400e+07]
#  [3.9080600e+07]
#  [2.5498100e+07]
#  [5.5264000e+07]
#  [4.2836300e+07]
#  [5.5259000e+07]
#  [3.5646000e+07]
#  [3.3930800e+07]
#  [2.4824500e+07]
#  [2.2350900e+07]
#  [2.2732000e+07]
#  [2.0462800e+07]
#  [1.7597500e+07]
#  [2.8068700e+07]
#  [2.2046100e+07]
#  [2.0346800e+07]
#  [2.7080800e+07]
#  [3.1360300e+07]
#  [3.2236200e+07]
#  [3.9157700e+07]
#  [4.7256900e+07]
#  [9.7241900e+07]
#  [5.8206300e+07]
#  [1.1018260e+08]
#  [1.0473980e+08]
#  [4.9164500e+07]
#  [4.8370000e+07]
#  [8.6301100e+07]
#  [1.3913160e+08]
#  [1.2152370e+08]
#  [8.8409800e+07]
#  [8.0391100e+07]
#  [7.6798100e+07]
#  [5.3484800e+07]
#  [6.9315600e+07]
#  [4.2955700e+07]
#  [5.4925900e+07]
#  [7.8258700e+07]
#  [8.2718100e+07]
#  [7.8446200e+07]
#  [5.6194800e+07]
#  [5.3455400e+07]
#  [6.4803700e+07]
#  [7.8729000e+07]
#  [6.3519600e+07]
#  [5.4608000e+07]
#  [4.4635700e+07]
#  [5.5032500e+07]
#  [5.5685600e+07]
#  [4.2172500e+07]
#  [3.3537200e+07]
#  [3.2046400e+07]
#  [2.9940800e+07]
#  [3.6664900e+07]
#  [2.5833000e+07]
#  [3.0374000e+07]
#  [4.2564300e+07]
#  [3.6342800e+07]
#  [4.0860100e+07]
#  [3.4533100e+07]
#  [3.8081800e+07]
#  [3.6598100e+07]
#  [4.5936100e+07]
#  [3.6381900e+07]
#  [3.0812000e+07]
#  [3.3187200e+07]
#  [3.3615700e+07]
#  [3.7708900e+07]
#  [3.8263400e+07]
#  [2.9729700e+07]
#  [6.5147000e+07]
#  [4.6219300e+07]
#  [4.6814300e+07]
#  [5.3324500e+07]
#  [6.0700500e+07]
#  [7.1963600e+07]
#  [9.1164900e+07]
#  [6.9877800e+07]
#  [4.4370000e+07]
#  [3.9395000e+07]
#  [3.6528500e+07]
#  [6.6319100e+07]
#  [4.6466100e+07]
#  [5.0330400e+07]
#  [3.2475800e+07]
#  [3.1280300e+07]
#  [2.5444900e+07]
#  [2.7931700e+07]
#  [2.9927400e+07]
#  [3.1145400e+07]
#  [2.2047900e+07]
#  [3.7057800e+07]
#  [3.8736500e+07]
#  [3.2611900e+07]
#  [2.7282800e+07]
#  [2.1485300e+07]
#  [3.3702100e+07]
#  [2.1222800e+07]
#  [2.7827700e+07]
#  [3.5963800e+07]
#  [5.5399500e+07]
#  [5.9722700e+07]
#  [5.5414900e+07]
#  [3.2992600e+07]
#  [2.8941600e+07]
#  [2.7188500e+07]
#  [3.2581600e+07]
#  [2.8682800e+07]
#  [3.9130300e+07]
#  [2.9426000e+07]
#  [3.2724000e+07]
#  [2.9290000e+07]
#  [3.2727200e+07]
#  [3.8842400e+07]
#  [3.5265200e+07]
#  [5.0890000e+07]
#  [3.5184500e+07]
#  [2.5717700e+07]
#  [3.9723000e+07]
#  [3.5336400e+07]
#  [5.3391600e+07]
#  [4.7262000e+07]
#  [6.4404600e+07]
#  [4.2183700e+07]
#  [3.0259900e+07]
#  [3.0252200e+07]
#  [3.1960800e+07]
#  [2.8438100e+07]
#  [5.7933100e+07]
#  [4.2066200e+07]
#  [2.5672500e+07]
#  [3.6484600e+07]
#  [2.7334100e+07]
#  [3.5558500e+07]
#  [2.9602200e+07]
#  [2.1443900e+07]
#  [3.3332100e+07]
#  [2.5960200e+07]
#  [3.5130800e+07]
#  [3.4249800e+07]
#  [2.5969200e+07]
#  [1.9336200e+07]
#  [3.4856900e+07]
#  [4.4793900e+07]
#  [3.8541900e+07]
#  [4.8499400e+07]
#  [3.9486000e+07]
#  [3.4034700e+07]
#  [2.1732900e+07]
#  [2.0441900e+07]
#  [2.9133300e+07]
#  [2.7104700e+07]
#  [2.7295700e+07]
#  [2.9628200e+07]
#  [2.8138300e+07]
#  [2.5453400e+07]
#  [2.4605400e+07]
#  [2.3970200e+07]
#  [3.2949200e+07]
#  [2.9399000e+07]
#  [4.0249400e+07]
#  [4.8741800e+07]
#  [4.1826600e+07]
#  [3.4097900e+07]
#  [3.5193100e+07]
#  [6.0912300e+07]
#  [7.6203200e+07]
#  [4.1927500e+07]
#  [4.6972900e+07]
#  [4.4652000e+07]
#  [3.6056800e+07]
#  [4.3338100e+07]
#  [9.7701600e+07]
#  [5.8076600e+07]
#  [6.1384600e+07]
#  [5.6375500e+07]
#  [7.6766000e+07]
#  [4.7232900e+07]
#  [5.6806500e+07]
#  [3.9411200e+07]
#  [4.1822300e+07]
#  [3.4847200e+07]
#  [4.3905100e+07]
#  [4.0120800e+07]
#  [4.3433900e+07]
#  [4.0419900e+07]
#  [3.4513500e+07]
#  [2.9091000e+07]
#  [3.1390300e+07]
#  [2.5469300e+07]
#  [3.6275800e+07]
#  [3.2597800e+07]
#  [4.7191300e+07]
#  [4.5760500e+07]
#  [3.8007000e+07]
#  [3.7310100e+07]
#  [3.0765300e+07]
#  [2.5135300e+07]
#  [3.3748900e+07]
#  [4.0265300e+07]
#  [4.3383800e+07]
#  [2.9256300e+07]
#  [5.0490700e+07]
#  [5.4937400e+07]
#  [3.2243000e+07]
#  [3.4730600e+07]
#  [3.3716900e+07]
#  [2.7872900e+07]
#  [2.8703300e+07]
#  [4.5721500e+07]
#  [4.5191700e+07]
#  [6.1715400e+07]
#  [7.0098700e+07]
#  [4.6954400e+07]
#  [5.1533300e+07]
#  [5.4447100e+07]
#  [8.1332700e+07]
#  [7.7766500e+07]
#  [8.4416600e+07]
#  [1.0534910e+08]
#  [6.7588800e+07]
#  [5.6005300e+07]
#  [3.9204000e+07]
#  [4.9973700e+07]
#  [5.2545800e+07]
#  [5.0166400e+07]
#  [7.5199200e+07]
#  [7.3858000e+07]
#  [8.2591400e+07]
#  [8.0492500e+07]
#  [6.5336800e+07]
#  [4.8899500e+07]
#  [3.7042200e+07]
#  [2.9595500e+07]
#  [3.2820700e+07]
#  [3.3113700e+07]
#  [3.2248500e+07]
#  [2.3850100e+07]
#  [3.4752900e+07]
#  [4.0575900e+07]
#  [5.8027200e+07]
#  [7.5739800e+07]
#  [7.0814300e+07]
#  [7.2652300e+07]
#  [9.1770500e+07]
#  [6.8295700e+07]
#  [5.4576400e+07]
#  [7.7994000e+07]
#  [8.0121200e+07]
#  [7.5450900e+07]
#  [8.1791500e+07]
#  [8.8610700e+07]
#  [1.4338890e+08]
#  [1.9868580e+08]
#  [1.2439840e+08]
#  [1.4655950e+08]
#  [9.5255700e+07]
#  [1.0816790e+08]
#  [9.4326400e+07]
#  [7.4433000e+07]
#  [7.8777100e+07]
#  [9.5384800e+07]
#  [8.6318300e+07]
#  [5.8198100e+07]
#  [6.4720900e+07]
#  [5.5766400e+07]
#  [1.1246850e+08]
#  [1.0156910e+08]
#  [8.0254400e+07]
#  [5.5128800e+07]
#  [5.8947100e+07]
#  [6.1801400e+07]
#  [8.0001500e+07]
#  [8.5967100e+07]
#  [8.6215400e+07]
#  [1.3061410e+08]
#  [7.8842100e+07]
#  [7.7515500e+07]
#  [6.7407000e+07]
#  [7.0609000e+07]
#  [7.1089400e+07]
#  [7.6936300e+07]
#  [8.9933800e+07]
#  [1.1615390e+08]
#  [6.4723400e+07]
#  [6.9362700e+07]
#  [6.6228400e+07]
#  [7.9802600e+07]
#  [7.6471000e+07]
#  [1.0524300e+08]
#  [6.7810000e+07]
#  [8.5446300e+07]
#  [7.3799100e+07]
#  [6.3345900e+07]
#  [7.0615500e+07]
#  [5.3555300e+07]
#  [5.7584200e+07]
#  [5.6833900e+07]
#  [6.8073000e+07]
#  [6.8757700e+07]
#  [6.7011400e+07]
#  [5.4527800e+07]
#  [4.5950200e+07]
#  [6.2738700e+07]
#  [9.0077100e+07]
#  [6.3777400e+07]
#  [6.1956100e+07]
#  [6.6107400e+07]
#  [7.2790200e+07]
#  [6.1367800e+07]
#  [7.3519400e+07]
#  [5.8560600e+07]
#  [5.6515700e+07]
#  [6.5500000e+07]
#  [7.5801000e+07]
#  [8.2562100e+07]
#  [1.0175590e+08]
#  [1.0581960e+08]
#  [1.1120420e+08]
#  [9.9450000e+07]
#  [9.1977900e+07]
#  [1.1551180e+08]
#  [7.8185500e+07]
#  [1.1608340e+08]
#  [1.5460740e+08]
#  [1.3957280e+08]
#  [1.1338730e+08]
#  [1.2412460e+08]
#  [1.4032610e+08]
#  [1.2091090e+08]
#  [8.3684900e+07]
#  [5.9190400e+07]
#  [6.2715300e+07]
#  [7.9477100e+07]
#  [7.9920700e+07]
#  [9.1764200e+07]
#  [6.3648400e+07]
#  [7.3491100e+07]
#  [6.7144500e+07]
#  [5.9462200e+07]
#  [6.6985600e+07]
#  [6.0968300e+07]
#  [6.5341700e+07]
#  [5.9291300e+07]
#  [6.0914700e+07]
#  [5.1785000e+07]
#  [4.4900300e+07]
#  [3.8342100e+07]
#  [5.5900500e+07]
#  [8.5963500e+07]
#  [9.4442000e+07]
#  [6.4697500e+07]
#  [8.6051400e+07]
#  [8.1910300e+07]
#  [8.2703400e+07]
#  [5.1633700e+07]
#  [6.7472900e+07]
#  [5.7457800e+07]
#  [5.8422300e+07]
#  [5.4151500e+07]
#  [6.1609800e+07]
#  [5.7302700e+07]
#  [7.9313600e+07]
#  [5.6675100e+07]
#  [6.1829300e+07]
#  [6.3194700e+07]
#  [5.6620100e+07]
#  [5.9895500e+07]
#  [5.5273900e+07]
#  [5.5797100e+07]
#  [7.3939400e+07]
#  [6.3741800e+07]
#  [6.3818100e+07]
#  [5.9519600e+07]
#  [5.5172600e+07]
#  [6.7769400e+07]
#  [5.5049400e+07]
#  [5.7127700e+07]
#  [4.0582400e+07]
#  [5.0074100e+07]
#  [6.9304400e+07]
#  [5.5139900e+07]
#  [5.7501000e+07]
#  [4.6358800e+07]
#  [4.8676500e+07]
#  [5.3735700e+07]
#  [3.8973700e+07]
#  [5.3894000e+07]
#  [4.3878500e+07]
#  [3.9764200e+07]
#  [5.1459600e+07]
#  [4.5897700e+07]
#  [4.0928400e+07]
#  [3.8266600e+07]
#  [4.1186900e+07]
#  [4.7842200e+07]
#  [4.1937200e+07]
#  [5.1770600e+07]
#  [5.1098900e+07]
#  [3.9497100e+07]
#  [3.8057100e+07]
#  [3.8098300e+07]
#  [6.9047700e+07]
#  [4.8321900e+07]
#  [5.1184500e+07]
#  [5.0044000e+07]
#  [5.7990700e+07]
#  [6.4666800e+07]
#  [5.7005400e+07]
#  [4.9260400e+07]
#  [5.5649800e+07]
#  [5.6125200e+07]
#  [4.5905700e+07]
#  [7.9562200e+07]
#  [5.4907200e+07]
#  [6.5299400e+07]
#  [7.9920400e+07]
#  [5.2613800e+07]
#  [5.1271100e+07]
#  [8.2931000e+07]
#  [6.2757100e+07]
#  [7.4815200e+07]
#  [7.1176700e+07]
#  [6.9780100e+07]
#  [7.9652100e+07]
#  [8.1216000e+07]
#  [7.8482400e+07]
#  [6.1267400e+07]
#  [6.6696900e+07]
#  [5.5766300e+07]
#  [5.3489400e+07]
#  [7.1354700e+07]
#  [6.0393000e+07]
#  [6.6522500e+07]
#  [5.0580200e+07]
#  [1.1289410e+08]
#  [7.7244300e+07]
#  [6.4576500e+07]
#  [6.9781000e+07]
#  [5.3115400e+07]
#  [6.0605500e+07]
#  [7.7897700e+07]
#  [6.3963600e+07]
#  [5.9014500e+07]
#  [6.3492400e+07]
#  [5.7760300e+07]
#  [6.2651300e+07]
#  [4.7742000e+07]
#  [4.5895900e+07]
#  [7.9803100e+07]
#  [7.0038900e+07]
#  [7.8313200e+07]
#  [4.7333800e+07]
#  [6.3213800e+07]
#  [6.4862100e+07]
#  [9.9256700e+07]
#  [6.6961800e+07]
#  [5.5290700e+07]
#  [7.3985400e+07]
#  [4.8859800e+07]
#  [5.5462100e+07]
#  [5.3588600e+07]
#  [4.0083500e+07]
#  [4.1873400e+07]
#  [4.6390000e+07]
#  [1.5498800e+07]
#  [3.8714200e+07]
#  [3.5618900e+07]
#  [7.4718100e+07]
#  [5.1547300e+07]
#  [5.3583200e+07]
#  [4.1482100e+07]
#  [5.3937600e+07]
#  [4.5614300e+07]
#  [4.2594900e+07]
#  [4.7860500e+07]
#  [3.5732500e+07]
#  [8.0667700e+07]
#  [6.4984400e+07]
#  [6.0554100e+07]
#  [6.8300400e+07]
#  [4.4167900e+07]
#  [5.1064200e+07]
#  [4.6394700e+07]
#  [6.0278400e+07]
#  [3.9373600e+07]
#  [3.8009000e+07]
#  [4.7139000e+07]
#  [4.5893600e+07]
#  [3.7858300e+07]
#  [4.2335300e+07]
#  [4.7754900e+07]
#  [4.5396700e+07]
#  [5.4659700e+07]
#  [4.5568700e+07]
#  [3.5247800e+07]
#  [4.4077000e+07]
#  [6.0600000e+07]
#  [4.4802900e+07]
#  [3.6269700e+07]
#  [4.7754500e+07]
#  [4.4150400e+07]
#  [6.0613600e+07]
#  [5.2799900e+07]
#  [4.4875100e+07]
#  [5.0872000e+07]
#  [5.1596300e+07]
#  [5.6441900e+07]
#  [4.9405800e+07]
#  [4.6705100e+07]
#  [6.7562200e+07]
#  [8.3070600e+07]
#  [7.6170800e+07]
#  [4.0802300e+07]
#  [6.7584000e+07]
#  [5.6720900e+07]
#  [4.9137800e+07]
#  [5.0050100e+07]
#  [3.9636700e+07]
#  [6.4079100e+07]
#  [4.3100600e+07]
#  [5.9498600e+07]
#  [5.8230700e+07]
#  [4.6526700e+07]
#  [5.1389200e+07]
#  [6.9294400e+07]
#  [7.4332000e+07]
#  [4.8995000e+07]
#  [4.8243100e+07]
#  [5.8287000e+07]
#  [5.3565900e+07]
#  [6.0511500e+07]
#  [5.6736300e+07]
#  [6.5955800e+07]
#  [5.0876300e+07]
#  [7.1456700e+07]
#  [9.8593600e+07]
#  [9.7123600e+07]
#  [7.3602500e+07]
#  [8.3631500e+07]
#  [9.8198100e+07]
#  [8.9923700e+07]
#  [5.6359500e+07]
#  [4.9757000e+07]
#  [7.5791900e+07]
#  [7.4576000e+07]
#  [5.7195200e+07]
#  [5.0287400e+07]
#  [4.8585900e+07]
#  [5.3274300e+07]
#  [5.8354800e+07]
#  [6.2138100e+07]
#  [4.7126800e+07]
#  [4.5875400e+07]
#  [6.2795700e+07]
#  [4.6916500e+07]
#  [4.5134700e+07]
#  [4.0113600e+07]
#  [6.2813300e+07]
#  [5.4613800e+07]
#  [5.6278300e+07]
#  [4.3007000e+07]
#  [4.6746900e+07]
#  [3.8960100e+07]
#  [6.2462100e+07]
#  [5.9002300e+07]
#  [4.4043100e+07]
#  [5.7121600e+07]
#  [5.5400500e+07]
#  [6.5430400e+07]
#  [5.9652500e+07]
#  [4.1013400e+07]
#  [5.6519400e+07]
#  [5.9882100e+07]
#  [5.0224500e+07]
#  [5.1776000e+07]
#  [3.6465800e+07]
#  [3.1768800e+07]
#  [6.0446600e+07]
#  [4.4278500e+07]
#  [4.8396200e+07]
#  [3.3375600e+07]
#  [4.0019200e+07]
#  [4.7486100e+07]
#  [6.4213500e+07]
#  [6.1462400e+07]
#  [4.3015900e+07]
#  [4.8216700e+07]
#  [6.2891200e+07]
#  [6.6862800e+07]
#  [6.3007000e+07]
#  [7.2652200e+07]
#  [6.5105400e+07]
#  [5.0488600e+07]
#  [5.3293500e+07]
#  [4.7266200e+07]
#  [4.1390400e+07]
#  [6.9225900e+07]
#  [4.7012227e+07]]
# [[353.1499939 ]
#  [353.88889035]
#  [354.91418577]
#  [355.48231931]
#  [356.32377636]
#  [357.17552904]
#  [358.0750948 ]
#  [358.97351349]
#  [359.92125603]
#  [360.90576064]
#  [361.94729684]
#  [362.99757591]
#  [364.04290302]
#  [365.0865515 ]
#  [366.08763262]
#  [367.13132306]
#  [368.22176344]
#  [369.33594251]
#  [370.51979885]
#  [371.74841876]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f1f1a535e694> in <cell line: 150>()
#     148 print(c)
#     149
# --> 150 prediction = np.concatenate((o, c, v), axis = 1)
#     151 print(prediction)
#     152
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 20 and the array at index 2 has size 865

# %%
#!pip install requests_html
import yfinance as yf
import pandas as pd
import sys
import datetime as dt
stock_list = ['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'amd', 'cdns', 'blrx', 'intc','riot', 'dis', 'team', 'gld', 'jd', 'rblx', 'adbe', 'crm', 'fslr', 'bac', 'jpm', 'unh', 'cost', 'meta',
              'tgt', 'nvda', 'xom', 'mvrl', 'avgo', 'tsla', 'u', 'snps', 'crsp', 'meta', 'uber', 'schw', 'arkg', 'arkk', 'gs', 'zs', 'enph', 'tsm', 'panw', 'crwd', 'lrcx', 'nflx', 'tgt',
              'tlt', 'uvxy', 'qqq', 'spy', 'iwm', 'yinn', 'ba', 'lmt', 'lulu', 'sbux', 'xpev', 'orcl','shop', 'abnb', 'twtr','mtch', 'docn', 'lyft', 'mdb', 'bynd', 'afrm', 'dish']

#stock_list = ['docn', 'snow', 'ddog', 'lyft', 'mdb', 'zs']
#stock_list = ['intc', 'nvda', 'amd', 'cdns', 'smh', 'snps', 'avgo']
#stock_list = ['aapl', 'meta', 'u', 'pypl', 'sq']
#stock_list = ['crsp', 'ilmn', 'dna', 'pfe']

def calculate_change_threadhold(data):
  av = data['change'].mean()
  std = data['change'].std()
  threadhold = av + std * 3
  return threadhold

def calculate_volume_threadhold(data):
  av = data['volume'].mean()
  std = data['volume'].std() 
  threadhold = av + std * 5
  return threadhold

def isUseful(data, im):
  distance_thread = 10
  date = dt.datetime.strptime(data,"%Y-%m-%d").date()
  curr = dt.datetime.now()
  cdate = curr.date()
  
  d = (date - cdate).days
  if (abs(d) <= 130):
    good = 1
  else:
    good = 0
  return good & im;

def getSymbols(sector, marketCapThread, priceThread):
  stock_symbols = yf.Tickers().tickers_by_sector("Technology")
  print(stock_symbols.symbols)
  for symbol in stock_symbols.symbols:
    stock = yf.Ticker(symbol)
    print(stock)
  return "yhoo"

#with open ('output.txt', 'w') as f:
#  sys.stdout = f

#stock_list = getSymbols("tech", "10_000_000_000", "100")
for stock in stock_list:
  options = yf.Ticker(stock).options

  for expiry in options:
#   print(expiry)
    chain = yf.Ticker(stock).option_chain(expiry)
    for s in range (2):
      callput_list = chain[s]

      thread_hold = calculate_volume_threadhold(callput_list)
      a = thread_hold
      b = calculate_change_threadhold
      
      
      for j in range(len(callput_list)):
        if (callput_list['volume'][j] > a) and isUseful(expiry, callput_list['inTheMoney'][j]): #and (callput_list['change'][j] > b):
          print(callput_list['contractSymbol'][j], "volume:", callput_list['volume'][j], "contractSize:", callput_list['contractSize'][j],
                "change", callput_list['change'][j], "percentChange", callput_list['percentChange'][j])
#          print("Stock:", callput_list)
#          print("Expiry Date:", callput_list['contractSymbol'][j], '  ---  ')
#      print(chain)
      
sys.stdout = sys.__stdout__
print ("end")
# Out:
# GOOGL230915C00120000 volume: 1801.0 contractSize: REGULAR change -3.4799995 percentChange -26.810476
# AMZN230616C00115000 volume: 17273.0 contractSize: REGULAR change -4.9700003 percentChange -41.07438
# AMZN230616P00150000 volume: 22670.0 contractSize: REGULAR change 5.039999 percentChange 21.492533
# AMZN230616P00190000 volume: 21347.0 contractSize: REGULAR change 5.220001 percentChange 8.198525
# AMZN230915C00117500 volume: 2121.0 contractSize: REGULAR change -3.9300003 percentChange -26.182547
# AMZN230915P00125000 volume: 5247.0 contractSize: REGULAR change 2.6699996 percentChange 39.380524
# DIS230616P00110000 volume: 22317.0 contractSize: REGULAR change -0.21999931 percentChange -1.2345641
# GLD230616P00190000 volume: 15145.0 contractSize: REGULAR change 1.8800001 percentChange 24.415586
# GLD230915P00182000 volume: 3050.0 contractSize: REGULAR change 0.5100002 percentChange 13.246759
# JD230616P00042500 volume: 2230.0 contractSize: REGULAR change 0.0 percentChange 0.0
# RBLX230609P00040000 volume: 3237.0 contractSize: REGULAR change 1.22 percentChange 381.25003
# ADBE230609P00420000 volume: 1548 contractSize: REGULAR change 4.1 percentChange 546.6667
# ADBE230721P00420000 volume: 378.0 contractSize: REGULAR change 4.71 percentChange 34.379562
# FSLR230616P00300000 volume: 1236.0 contractSize: REGULAR change 13.300003 percentChange 13.926704
# FSLR230915P00195000 volume: 1870.0 contractSize: REGULAR change 2.1999989 percentChange 13.253005
# BAC230818C00029000 volume: 3028 contractSize: REGULAR change 0.21000004 percentChange 12.574853
# NVDA230609P00380000 volume: 41006.0 contractSize: REGULAR change 5.0699997 percentChange 192.77565
# NVDA230616P00380000 volume: 9888.0 contractSize: REGULAR change 5.65 percentChange 82.48175
# NVDA230818P00390000 volume: 1341.0 contractSize: REGULAR change 4.7300014 percentChange 16.790918
# AVGO230623C00600000 volume: 1228.0 contractSize: REGULAR change 0.0 percentChange 0.0
# AVGO230721P00800000 volume: 180.0 contractSize: REGULAR change -8.09 percentChange -19.307877
# AVGO230915C00730000 volume: 396.0 contractSize: REGULAR change 0.0 percentChange 0.0
# TSLA230616P00225000 volume: 16413.0 contractSize: REGULAR change -2.1500006 percentChange -22.994658
# TSLA230616P00400000 volume: 17223.0 contractSize: REGULAR change -3.8099976 percentChange -2.1147854
# TSLA230915P00583330 volume: 1690.0 contractSize: REGULAR change 0.0 percentChange 0.0
# GS230616P00370000 volume: 1617 contractSize: REGULAR change -8.400002 percentChange -19.811323
# GS230616P00385000 volume: 1551 contractSize: REGULAR change 0.0 percentChange 0.0
# GS230721P00410000 volume: 10610 contractSize: REGULAR change 0.0 percentChange 0.0
# ZS230609C00144000 volume: 463.0 contractSize: REGULAR change -5.96 percentChange -68.505745
# ZS230609P00145000 volume: 1588 contractSize: REGULAR change 2.0300002 percentChange 548.6487
# ZS230721P00230000 volume: 380 contractSize: REGULAR change 0.0 percentChange 0.0
# PANW230609P00220000 volume: 1869 contractSize: REGULAR change 3.5100002 percentChange 585.00006
# CRWD230609P00150000 volume: 1673.0 contractSize: REGULAR change 1.22 percentChange 122.0
# CRWD230616P00150000 volume: 724.0 contractSize: REGULAR change 1.3900001 percentChange 53.461544
# CRWD230623P00150000 volume: 134.0 contractSize: REGULAR change 1.46 percentChange 42.44186
# LRCX230721C00555000 volume: 387.0 contractSize: REGULAR change 1.6800003 percentChange 2.584616
# LRCX230721C00565000 volume: 385.0 contractSize: REGULAR change 3.5499992 percentChange 6.4451685
# NFLX230609P00400000 volume: 9033.0 contractSize: REGULAR change -0.42999983 percentChange -7.2512617
# NFLX230616P00400000 volume: 3155 contractSize: REGULAR change 0.14999962 percentChange 1.5384576
# TLT230616P00110000 volume: 26951.0 contractSize: REGULAR change 1.4500003 percentChange 18.954252
# TLT230616P00114000 volume: 25066.0 contractSize: REGULAR change 1.4500008 percentChange 12.446359
# QQQ230609P00350000 volume: 63540.0 contractSize: REGULAR change 2.15 percentChange 390.9091
# QQQ230612P00350000 volume: 15194.0 contractSize: REGULAR change 2.29 percentChange 260.22726
# QQQ230613P00350000 volume: 13195.0 contractSize: REGULAR change 2.39 percentChange 191.20001
# QQQ230614P00353000 volume: 11977.0 contractSize: REGULAR change 3.18 percentChange 116.911766
# QQQ230616P00350000 volume: 86391.0 contractSize: REGULAR change 2.53 percentChange 116.05504
# QQQ230623P00350000 volume: 6201.0 contractSize: REGULAR change 2.5700002 percentChange 83.44157
# QQQ230630P00353000 volume: 16803 contractSize: REGULAR change 3.1500006 percentChange 63.63638
# QQQ230721P00350000 volume: 21118.0 contractSize: REGULAR change 2.54 percentChange 43.270866
# QQQ230721P00355000 volume: 20581.0 contractSize: REGULAR change 3.2099996 percentChange 41.259636
# QQQ230915P00350000 volume: 8782.0 contractSize: REGULAR change 2.2300005 percentChange 21.339718
# QQQ230929C00334000 volume: 357.0 contractSize: REGULAR change 0.0 percentChange 0.0
# QQQ230929P00350000 volume: 609.0 contractSize: REGULAR change 2.3400002 percentChange 20.25974
# SPY230607P00427000 volume: 575143.0 contractSize: REGULAR change -0.01000002 percentChange -2.0408204
# SPY230608P00427000 volume: 168050.0 contractSize: REGULAR change 0.28000003 percentChange 34.146343
# SPY230609P00427000 volume: 105356 contractSize: REGULAR change 0.39 percentChange 34.821426
# IWM230616C00185000 volume: 50523.0 contractSize: REGULAR change 2.25 percentChange 100.0
# IWM230707P00190000 volume: 1371.0 contractSize: REGULAR change -1.9200001 percentChange -27.234041
# BA230915C00210000 volume: 2292.0 contractSize: REGULAR change 2.5500002 percentChange 19.615387
# LMT230616C00400000 volume: 1620.0 contractSize: REGULAR change 0.0 percentChange 0.0
# LMT230616P00480000 volume: 1727.0 contractSize: REGULAR change -6.8500004 percentChange -28.54167
# LMT230616P00490000 volume: 1745.0 contractSize: REGULAR change -4.200001 percentChange -13.46154
# LULU230609P00355000 volume: 966.0 contractSize: REGULAR change 0.16000009 percentChange 5.2631607
# SBUX230616P00110000 volume: 9715.0 contractSize: REGULAR change 0.05000019 percentChange 0.42553353
# ORCL230630P00107000 volume: 1757.0 contractSize: REGULAR change 1.0500002 percentChange 31.34329
# MDB230609P00370000 volume: 621.0 contractSize: REGULAR change 5.48 percentChange 438.4
# MDB230609P00375000 volume: 650.0 contractSize: REGULAR change 7.7 percentChange 349.99997
# MDB230616P00370000 volume: 1078.0 contractSize: REGULAR change 8.450001 percentChange 202.15314
# MDB230818P00370000 volume: 332 contractSize: REGULAR change 7.5200005 percentChange 29.996014
